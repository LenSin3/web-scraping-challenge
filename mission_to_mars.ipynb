# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## NASA Mars News

# %%
url = 'https://mars.nasa.gov/news/'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

quotes = soup.find_all('div', class_ = 'content_title')

paragraphs = soup.find_all('div', class_="article_teaser_body")

# %%
count = 0
titles = []
for quote in quotes:
    
    count = count + 1
    print('Extracting News Title')
    print('.....................')
        
    news_title = quote.text
    print(count, news_title)
    
    
     
for paragraph in paragraphs:
    
    
    
    print('Extracting Title Paragraph')
    print('.....................')
    news_p = paragraph.text
    print(news_p)
# Out:
# Extracting News Title
# .....................
# 1 Mars Now
# Extracting News Title
# .....................
# 2 NASA's Perseverance Rover Is Midway to Mars
# Extracting News Title
# .....................
# 3 Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth
# Extracting News Title
# .....................
# 4 NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars
# Extracting News Title
# .....................
# 5 NASA InSight's 'Mole' Is Out of Sight
# Extracting News Title
# .....................
# 6 NASA's Perseverance Rover Will Peer Beneath Mars' Surface
# Extracting News Title
# .....................
# 7 AI Is Helping Scientists Discover Fresh Craters on Mars
# Extracting News Title
# .....................
# 8 NASA's New Mars Rover Is Ready for Space Lasers
# Extracting News Title
# .....................
# 9 NASA's New Mars Rover Will Use X-Rays to Hunt Fossils
# Extracting News Title
# .....................
# 10 My Culture, My Voice
# Extracting News Title
# .....................
# 11 NASA Readies Perseverance Mars Rover's Earthly Twin
# Extracting News Title
# .....................
# 12 NASA Engineers Checking InSight's Weather Sensors
# Extracting News Title
# .....................
# 13 Follow NASA's Perseverance Rover in Real Time on Its Way to Mars
# Extracting News Title
# .....................
# 14 NASA Establishes Board to Initially Review Mars Sample Return Plans
# Extracting News Title
# .....................
# 15 NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight
# Extracting News Title
# .....................
# 16 Celebrate Mars Reconnaissance Orbiter's Views From Above
# Extracting News Title
# .....................
# 17 NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light
# Extracting News Title
# .....................
# 18 8 Martian Postcards to Celebrate Curiosity's Landing Anniversary
# Extracting News Title
# .....................
# 19 NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet
# Extracting News Title
# .....................
# 20 NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars
# Extracting News Title
# .....................
# 21 A New Video Captures the Science of NASA's Perseverance Mars Rover
# Extracting News Title
# .....................
# 22 NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch
# Extracting News Title
# .....................
# 23 NASA's Mars Perseverance Rover Passes Flight Readiness Review
# Extracting News Title
# .....................
# 24 NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
# Extracting News Title
# .....................
# 25 6 Things to Know About NASA's Ingenuity Mars Helicopter
# Extracting News Title
# .....................
# 26 Join NASA for the Launch of the Mars 2020 Perseverance Rover
# Extracting News Title
# .....................
# 27 NASA's Perseverance Rover Attached to Atlas V Rocket
# Extracting News Title
# .....................
# 28 7 Things to Know About the Mars 2020 Perseverance Rover Mission
# Extracting News Title
# .....................
# 29 NASA's InSight Flexes Its Arm While Its 'Mole' Hits Pause
# Extracting News Title
# .....................
# 30 Curiosity Mars Rover's Summer Road Trip Has Begun
# Extracting News Title
# .....................
# 31 How NASA's Mars Helicopter Will Reach the Red Planet's Surface
# Extracting News Title
# .....................
# 32 The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
# Extracting News Title
# .....................
# 33 NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
# Extracting News Title
# .....................
# 34 While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus
# Extracting News Title
# .....................
# 35 NASA's Mars Rover Drivers Need Your Help
# Extracting News Title
# .....................
# 36 Three New Views of Mars' Moon Phobos
# Extracting News Title
# .....................
# 37 The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover
# Extracting News Title
# .....................
# 38 The Detective Aboard NASA's Perseverance Rover
# Extracting News Title
# .....................
# 39 MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss
# Extracting News Title
# .....................
# 40 Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch
# Extracting News Title
# .....................
# 41 NASA Wins 4 Webbys, 4 People's Voice Awards
# Extracting News Title
# .....................
# 42
#
# Alabama High School Student Names NASA's Mars Helicopter
#
#
# Extracting News Title
# .....................
# 43
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
# Extracting News Title
# .....................
# 44
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
# Extracting News Title
# .....................
# 45
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
# Extracting News Title
# .....................
# 46
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
# Extracting News Title
# .....................
# 47
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
# Extracting News Title
# .....................
# 48
#
# Alabama High School Student Names NASA's Mars Helicopter
#
#
# Extracting News Title
# .....................
# 49
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
# Extracting News Title
# .....................
# 50
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
# Extracting News Title
# .....................
# 51
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
# Extracting News Title
# .....................
# 52
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
# Extracting News Title
# .....................
# 53
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
# Extracting Title Paragraph
# .....................
# Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.
# Extracting Title Paragraph
# .....................
# Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.
# Extracting Title Paragraph
# .....................
# For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.
# Extracting Title Paragraph
# .....................
# Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.
# Extracting Title Paragraph
# .....................
# The agency's newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life.
# Extracting Title Paragraph
# .....................
# It's the first time machine learning has been used to find previously unknown craters on the Red Planet.
# Extracting Title Paragraph
# .....................
# Perseverance is one of a few Mars spacecraft carrying laser retroreflectors. The devices could provide new science and safer Mars landings in the future.
# Extracting Title Paragraph
# .....................
# PIXL, an instrument on the end of the Perseverance rover's arm, will search for chemical fingerprints left by ancient microbes.
# Extracting Title Paragraph
# .....................
# In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.
# Extracting Title Paragraph
# .....................
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.
# Extracting Title Paragraph
# .....................
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# Extracting Title Paragraph
# .....................
# A crisply rendered web application can show you where the agency's Mars 2020 mission is right now as it makes its way to the Red Planet for a Feb. 18, 2021, landing.
# Extracting Title Paragraph
# .....................
# The board will assist with analysis of current plans and goals for one of the most difficult missions humanity has ever undertaken.
# Extracting Title Paragraph
# .....................
# Headed to the Red Planet with the Perseverance rover, the pioneering helicopter is powered up for the first time in interplanetary space as part of a systems check.
# Extracting Title Paragraph
# .....................
# Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.
# Extracting Title Paragraph
# .....................
# Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.
# Extracting Title Paragraph
# .....................
# The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.
# Extracting Title Paragraph
# .....................
# The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021.
# Extracting Title Paragraph
# .....................
# In a Q&A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch.
# Extracting Title Paragraph
# .....................
# With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.
# Extracting Title Paragraph
# .....................
# There are lots of ways to participate in the historic event, which is targeted for July 30.
# Extracting Title Paragraph
# .....................
# ​The agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27.
# Extracting Title Paragraph
# .....................
# Starting July 27, news activities will cover everything from mission engineering and science to returning samples from Mars to, of course, the launch itself.
# Extracting Title Paragraph
# .....................
# The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.
# Extracting Title Paragraph
# .....................
# No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.
# Extracting Title Paragraph
# .....................
# Ready for its launch later in the month, the Mars-bound rover will touch terra firma no more.
# Extracting Title Paragraph
# .....................
# NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Extracting Title Paragraph
# .....................
# Now that the lander's robotic arm has helped the mole get underground, it will resume science activities that have been on hold.
# Extracting Title Paragraph
# .....................
# After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Extracting Title Paragraph
# .....................
# The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.
# Extracting Title Paragraph
# .....................
# The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Extracting Title Paragraph
# .....................
# Learn more about the agency's next Red Planet mission during a live event on June 17.
# Extracting Title Paragraph
# .....................
# This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.
# Extracting Title Paragraph
# .....................
# Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.
# Extracting Title Paragraph
# .....................
# Taken with the infrared camera aboard NASA's Odyssey orbiter, they reveal temperature variations on the small moon as it drifts into and out of Mars’ shadow.
# Extracting Title Paragraph
# .....................
# Two astronauts collected Moon rocks on Apollo 11. It will take three robotic systems working together to gather up the first Mars rock samples for return to Earth.
# Extracting Title Paragraph
# .....................
# An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.
# Extracting Title Paragraph
# .....................
# Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.
# Extracting Title Paragraph
# .....................
# A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff.
# Extracting Title Paragraph
# .....................
# Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.

# %% [markdown]
# ## JPL Mars Space Images - Featured Image

# %%
# image_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
# browser.visit(image_url)

# %%
# html = browser.html
# soup = BeautifulSoup(html, 'html.parser')

# image = soup.find('li', {'class':'fancybox-thumb-active'})

# %%
# image

# %% [markdown]
# ## Mars Facts

# %%
import pandas as pd

# %%
table_url = 'https://space-facts.com/mars/'

# %%
mars_df = pd.read_html(str(table_url))[0]

# %%
mars_df.rename(columns = {0: 'Fact', 1:'Data'}, inplace=True)
mars_df
# Out:
#                    Fact                           Data
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mars_df_html = mars_df.to_html(index = False)

# %%
mars_df_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>Fact</th>\n      <th>Data</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <td>Moons:</td>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <td>Surface Temperature:</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <td>First Record:</td>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <td>Recorded By:</td>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %% [markdown]
# ## Mars Hemispheres

# %%
mars_hem_url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'

# %%
hemisphere_image_url = [{'title' : 'Cerberus hemisphere',\
                         'img_url': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/cerberus_enhanced#open'},
                       {'title': 'Valles Marineris Hemisphere', 'img_url': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/valles_marineris_enhanced'},
                       {'title': 'Syrtis Major Hemisphere ', 'img_url': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/syrtis_major_enhanced'},
                       {'title': 'Schiaparelli Hemisphere', 'img_url': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/schiaparelli_enhanced'}]

# %%
browser.quit()
